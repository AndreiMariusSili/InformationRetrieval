# %%
import copy
import gensim
import logging
import pyndri
import pyndri.compat
import sys

# Create logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# Create STDERR handler
handler = logging.StreamHandler(sys.stderr)
# ch.setLevel(logging.DEBUG)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Set STDERR handler as the only handler 
logger.handlers = [handler]

index = pyndri.Index('../index/')
logging.info('Loading vocabulary.')
dictionary = pyndri.extract_dictionary(index)
sentences = pyndri.compat.IndriSentences(index, dictionary)
# Out:
# root - INFO - Loading vocabulary.

# %%
logging.info('Initializing word2vec.')

word2vec_init = gensim.models.Word2Vec(
    size=300,  # Embedding size
    window=5,  # One-sided window size
    sg=True,  # Skip-gram.
    min_count=1,  # Minimum word frequency.
    sample=1e-3,  # Sub-sample threshold.
    hs=False,  # Hierarchical softmax.
    negative=10,  # Number of negative examples.
    iter=1,  # Number of iterations.
    workers=8,  # Number of workers.
)

logging.info('Constructing word2vec vocabulary.')

# Build vocab.
word2vec_init.build_vocab(sentences, trim_rule=None)

models = [word2vec_init]

for epoch in range(1, 2):
    logging.info('Epoch %d', epoch)

    model = copy.deepcopy(models[-1])
    model.train(sentences, total_examples=model.corpus_count, epochs=1)

    models.append(model)

logging.info('Trained models: %s', models)
# Out:
# root - INFO - Initializing word2vec.
# root - INFO - Constructing word2vec vocabulary.
# gensim.models.word2vec - INFO - collecting all words and their counts
# gensim.models.word2vec - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #10000, processed 2607270 words, keeping 73866 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #20000, processed 5208413 words, keeping 101162 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #30000, processed 7779447 words, keeping 121185 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #40000, processed 10402346 words, keeping 138774 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #50000, processed 12981963 words, keeping 153153 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #60000, processed 15578280 words, keeping 165943 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #70000, processed 18181273 words, keeping 177185 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #80000, processed 20777766 words, keeping 188142 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #90000, processed 23336840 words, keeping 199575 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #100000, processed 25881289 words, keeping 211216 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #110000, processed 28375782 words, keeping 221773 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #120000, processed 30893236 words, keeping 231132 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #130000, processed 33417709 words, keeping 240313 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #140000, processed 35992742 words, keeping 248661 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #150000, processed 38498286 words, keeping 256455 word types
# gensim.models.word2vec - INFO - PROGRESS: at sentence #160000, processed 41037535 words, keeping 263913 word types
# gensim.models.word2vec - INFO - collected 267318 word types from a corpus of 42208958 raw words and 164597 sentences
# gensim.models.word2vec - INFO - Loading a fresh vocabulary
# gensim.models.word2vec - INFO - min_count=1 retains 267318 unique words (100% of original 267318, drops 0)
# gensim.models.word2vec - INFO - min_count=1 leaves 42208958 word corpus (100% of original 42208958, drops 0)
# gensim.models.word2vec - INFO - deleting the raw counts dictionary of 267318 items
# gensim.models.word2vec - INFO - sample=0.001 downsamples 10 most-common words
# gensim.models.word2vec - INFO - downsampling leaves estimated 42045982 word corpus (99.6% of prior 42208958)
# gensim.models.word2vec - INFO - estimated required memory for 267318 words and 300 dimensions: 775222200 bytes
# gensim.models.word2vec - INFO - resetting layer weights
# root - INFO - Epoch 1
# gensim.models.word2vec - INFO - training model with 8 workers on 267318 vocabulary and 300 features, using sg=1 hs=False sample=0.001 negative=10 window=5
# gensim.models.word2vec - INFO - PROGRESS: at 0.38% examples, 156693 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 0.84% examples, 171910 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 1.27% examples, 172504 words/s, in_qsize 15, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 1.74% examples, 179182 words/s, in_qsize 15, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 2.22% examples, 185776 words/s, in_qsize 14, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 2.73% examples, 189412 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 3.22% examples, 191677 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 3.70% examples, 192217 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 4.20% examples, 195227 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 4.69% examples, 195478 words/s, in_qsize 15, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 5.26% examples, 197604 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 5.72% examples, 196968 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 6.20% examples, 197342 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 6.70% examples, 198173 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 7.19% examples, 198096 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 7.67% examples, 198489 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 8.16% examples, 198886 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 8.68% examples, 199206 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 9.19% examples, 199739 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 9.71% examples, 200435 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 10.17% examples, 200132 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 10.65% examples, 200220 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 11.07% examples, 198760 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 11.36% examples, 195659 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 11.76% examples, 194830 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 12.19% examples, 194295 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 12.63% examples, 193984 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 13.18% examples, 194851 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 13.58% examples, 193687 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 14.02% examples, 193120 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 14.48% examples, 192887 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 14.93% examples, 192597 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 15.26% examples, 190705 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 15.67% examples, 189979 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 16.17% examples, 189788 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 16.61% examples, 189535 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 17.02% examples, 189202 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 17.41% examples, 188500 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 17.89% examples, 188673 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 18.37% examples, 188851 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 18.86% examples, 189177 words/s, in_qsize 14, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 19.30% examples, 189102 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 19.74% examples, 189050 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 20.20% examples, 188860 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 20.65% examples, 188829 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 21.11% examples, 188899 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 21.58% examples, 189034 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 22.06% examples, 189049 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 22.52% examples, 189292 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 23.03% examples, 189636 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 23.48% examples, 189529 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 23.96% examples, 189719 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 24.41% examples, 189750 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 24.86% examples, 189705 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 25.33% examples, 189958 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 25.81% examples, 189908 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 26.29% examples, 190172 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 26.78% examples, 190259 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 27.28% examples, 190457 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 27.79% examples, 190790 words/s, in_qsize 14, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 28.25% examples, 190746 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 28.74% examples, 190911 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 29.24% examples, 191022 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 29.72% examples, 190831 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 30.22% examples, 191153 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at
words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 72.60% examples, 191645 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 73.11% examples, 191725 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 73.54% examples, 191680 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 74.04% examples, 191725 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 74.58% examples, 191805 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 75.11% examples, 191910 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 75.56% examples, 191851 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 76.09% examples, 191993 words/s, in_qsize 14, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 76.55% examples, 191878 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 77.09% examples, 192052 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 77.48% examples, 191825 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 77.95% examples, 191835 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 78.41% examples, 191850 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 78.91% examples, 191931 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 79.37% examples, 191913 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 79.92% examples, 191972 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 80.45% examples, 192136 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 80.86% examples, 192046 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 81.36% examples, 192165 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 81.85% examples, 192194 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 82.36% examples, 192216 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 82.86% examples, 192264 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 83.31% examples, 192180 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 83.66% examples, 191923 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 84.10% examples, 191743 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 84.50% examples, 191467 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 84.86% examples, 191263 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 85.24% examples, 191084 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 85.70% examples, 191090 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 86.14% examples, 191055 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 86.66% examples, 191116 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 87.10% examples, 190878 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 87.39% examples, 190530 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 87.68% examples, 190022 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 88.02% examples, 189789 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 88.44% examples, 189687 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 88.98% examples, 189788 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 89.49% examples, 189850 words/s, in_qsize 15, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 90.00% examples, 189918 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 90.48% examples, 189939 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 91.02% examples, 190059 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 91.49% examples, 190025 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 91.93% examples, 189961 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 92.23% examples, 189509 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 92.50% examples, 189137 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 92.89% examples, 188851 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 93.25% examples, 188675 words/s, in_qsize 15, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 93.77% examples, 188699 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 94.20% examples, 188621 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 94.75% examples, 188749 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 95.22% examples, 188763 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 95.56% examples, 188439 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 95.93% examples, 188204 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 96.39% examples, 188148 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 96.86% examples, 188177 words/s, in_qsize 14, out_qsize 1
# gensim.models.word2vec - INFO - PROGRESS: at 97.28% examples, 188065 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 97.71% examples, 187910 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 98.14% examples, 187842 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 98.60% examples, 187814 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 98.99% examples, 187713 words/s, in_qsize 15, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 99.40% examples, 187615 words/s, in_qsize 16, out_qsize 0
# gensim.models.word2vec - INFO - PROGRESS: at 99.72% examples, 187354 words/s, in_qsize 13, out_qsize 0
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 7 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 6 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 5 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 4 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 3 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 2 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 1 more threads
# gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# gensim.models.word2vec - INFO - training on 42208958 raw words (42045896 effective words) took 224.4s, 187366 effective words/s
# root - INFO - Trained models: [<gensim.models.word2vec.Word2Vec object at 0x11a653fd0>, <gensim.models.word2vec.Word2Vec object at 0x1182e5dd8>]

# %%
final_model = models[-1]

# %%
final_model.save("../models/Word2Vec")
# Out:
# gensim.utils - INFO - saving Word2Vec object under ../models/Word2Vec, separately None
# gensim.utils - INFO - storing np array 'syn0' to ../models/Word2Vec.wv.syn0.npy
# gensim.utils - INFO - not storing attribute syn0norm
# gensim.utils - INFO - storing np array 'syn1neg' to ../models/Word2Vec.syn1neg.npy
# gensim.utils - INFO - not storing attribute cum_table
# gensim.utils - INFO - saved ../models/Word2Vec

# %%
m = gensim.models.Word2Vec.load('../models/Word2Vec_model')

# %%
m.wv['provosts']

# %%
dictionary.token2id['provosts']
